# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /Users/nubz/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=50,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/50
#  - 48s - loss: 1.0827 - acc: 0.6153 - val_loss: 0.9771 - val_acc: 0.6630
#
# Epoch 00001: val_loss improved from inf to 0.97713, saving model to model.weights.best.hdf5
# Epoch 2/50
#  - 47s - loss: 1.0050 - acc: 0.6442 - val_loss: 0.9380 - val_acc: 0.6728
#
# Epoch 00002: val_loss improved from 0.97713 to 0.93800, saving model to model.weights.best.hdf5
# Epoch 3/50
#  - 51s - loss: 0.9404 - acc: 0.6689 - val_loss: 0.8884 - val_acc: 0.6932
#
# Epoch 00003: val_loss improved from 0.93800 to 0.88838, saving model to model.weights.best.hdf5
# Epoch 4/50
#  - 46s - loss: 0.8886 - acc: 0.6869 - val_loss: 0.8717 - val_acc: 0.7010
#
# Epoch 00004: val_loss improved from 0.88838 to 0.87167, saving model to model.weights.best.hdf5
# Epoch 5/50
#  - 45s - loss: 0.8527 - acc: 0.6992 - val_loss: 0.8185 - val_acc: 0.7146
#
# Epoch 00005: val_loss improved from 0.87167 to 0.81846, saving model to model.weights.best.hdf5
# Epoch 6/50
#  - 45s - loss: 0.8157 - acc: 0.7120 - val_loss: 0.8109 - val_acc: 0.7164
#
# Epoch 00006: val_loss improved from 0.81846 to 0.81089, saving model to model.weights.best.hdf5
# Epoch 7/50
#  - 45s - loss: 0.7849 - acc: 0.7215 - val_loss: 0.8288 - val_acc: 0.7116
#
# Epoch 00007: val_loss did not improve
# Epoch 8/50
#  - 58s - loss: 0.7547 - acc: 0.7323 - val_loss: 0.7938 - val_acc: 0.7276
#
# Epoch 00008: val_loss improved from 0.81089 to 0.79382, saving model to model.weights.best.hdf5
# Epoch 9/50
#  - 65s - loss: 0.7218 - acc: 0.7445 - val_loss: 0.8044 - val_acc: 0.7220
#
# Epoch 00009: val_loss did not improve
# Epoch 10/50
#  - 59s - loss: 0.7050 - acc: 0.7483 - val_loss: 0.7597 - val_acc: 0.7404
#
# Epoch 00010: val_loss improved from 0.79382 to 0.75966, saving model to model.weights.best.hdf5
# Epoch 11/50
#  - 49s - loss: 0.6790 - acc: 0.7576 - val_loss: 0.7600 - val_acc: 0.7404
#
# Epoch 00011: val_loss did not improve
# Epoch 12/50
#  - 49s - loss: 0.6627 - acc: 0.7638 - val_loss: 0.7873 - val_acc: 0.7310
#
# Epoch 00012: val_loss did not improve
# Epoch 13/50
#  - 49s - loss: 0.6388 - acc: 0.7730 - val_loss: 0.7858 - val_acc: 0.7348
#
# Epoch 00013: val_loss did not improve
# Epoch 14/50
#  - 57s - loss: 0.6210 - acc: 0.7772 - val_loss: 0.7352 - val_acc: 0.7472
#
# Epoch 00014: val_loss improved from 0.75966 to 0.73522, saving model to model.weights.best.hdf5
# Epoch 15/50
#  - 47s - loss: 0.6046 - acc: 0.7843 - val_loss: 0.7337 - val_acc: 0.7510
#
# Epoch 00015: val_loss improved from 0.73522 to 0.73374, saving model to model.weights.best.hdf5
# Epoch 16/50
#  - 50s - loss: 0.5909 - acc: 0.7889 - val_loss: 0.7591 - val_acc: 0.7424
#
# Epoch 00016: val_loss did not improve
# Epoch 17/50
#  - 54s - loss: 0.5857 - acc: 0.7917 - val_loss: 0.7432 - val_acc: 0.7420
#
# Epoch 00017: val_loss did not improve
# Epoch 18/50
#  - 47s - loss: 0.5694 - acc: 0.7956 - val_loss: 0.7852 - val_acc: 0.7338
#
# Epoch 00018: val_loss did not improve
# Epoch 19/50
#  - 51s - loss: 0.5471 - acc: 0.8052 - val_loss: 0.7772 - val_acc: 0.7324
#
# Epoch 00019: val_loss did not improve
# Epoch 20/50
#  - 49s - loss: 0.5478 - acc: 0.8053 - val_loss: 0.7516 - val_acc: 0.7430
#
# Epoch 00020: val_loss did not improve
# Epoch 21/50
#  - 47s - loss: 0.5345 - acc: 0.8082 - val_loss: 0.7335 - val_acc: 0.7498
#
# Epoch 00021: val_loss improved from 0.73374 to 0.73350, saving model to model.weights.best.hdf5
# Epoch 22/50
#  - 55s - loss: 0.5260 - acc: 0.8122 - val_loss: 0.7554 - val_acc: 0.7458
#
# Epoch 00022: val_loss did not improve
# Epoch 23/50
#  - 61s - loss: 0.5155 - acc: 0.8148 - val_loss: 0.7606 - val_acc: 0.7440
#
# Epoch 00023: val_loss did not improve
# Epoch 24/50
#  - 55s - loss: 0.5141 - acc: 0.8168 - val_loss: 0.7476 - val_acc: 0.7434
#
# Epoch 00024: val_loss did not improve
# Epoch 25/50
#  - 51s - loss: 0.4975 - acc: 0.8212 - val_loss: 0.7769 - val_acc: 0.7396
#
# Epoch 00025: val_loss did not improve
# Epoch 26/50
#  - 56s - loss: 0.4940 - acc: 0.8234 - val_loss: 0.7803 - val_acc: 0.7386
#
# Epoch 00026: val_loss did not improve
# Epoch 27/50
#  - 60s - loss: 0.4861 - acc: 0.8260 - val_loss: 0.7477 - val_acc: 0.7466
#
# Epoch 00027: val_loss did not improve
# Epoch 28/50
#  - 62s - loss: 0.4788 - acc: 0.8299 - val_loss: 0.7439 - val_acc: 0.7552
#
# Epoch 00028: val_loss did not improve
# Epoch 29/50
#  - 62s - loss: 0.4700 - acc: 0.8318 - val_loss: 0.7374 - val_acc: 0.7586
#
# Epoch 00029: val_loss did not improve
# Epoch 30/50
#  - 56s - loss: 0.4707 - acc: 0.8316 - val_loss: 0.7625 - val_acc: 0.7434
#
# Epoch 00030: val_loss did not improve
# Epoch 31/50
#  - 58s - loss: 0.4674 - acc: 0.8334 - val_loss: 0.7768 - val_acc: 0.7440
#
# Epoch 00031: val_loss did not improve
# Epoch 32/50
#  - 52s - loss: 0.4516 - acc: 0.8398 - val_loss: 0.7468 - val_acc: 0.7530
#
# Epoch 00032: val_loss did not improve
# Epoch 33/50
#  - 51s - loss: 0.4527 - acc: 0.8400 - val_loss: 0.7576 - val_acc: 0.7602
#
# Epoch 00033: val_loss did not improve
# Epoch 34/50
#  - 51s - loss: 0.4491 - acc: 0.8396 - val_loss: 0.7628 - val_acc: 0.7532
#
# Epoch 00034: val_loss did not improve
# Epoch 35/50
#  - 51s - loss: 0.4440 - acc: 0.8411 - val_loss: 0.7475 - val_acc: 0.7538
#
# Epoch 00035: val_loss did not improve
# Epoch 36/50
#  - 47s - loss: 0.4363 - acc: 0.8445 - val_loss: 0.7491 - val_acc: 0.7620
#
# Epoch 00036: val_loss did not improve
# Epoch 37/50
#  - 48s - loss: 0.4326 - acc: 0.8453 - val_loss: 0.7376 - val_acc: 0.7538
#
# Epoch 00037: val_loss did not improve
# Epoch 38/50
#  - 50s - loss: 0.4230 - acc: 0.8499 - val_loss: 0.7503 - val_acc: 0.7500
#
# Epoch 00038: val_loss did not improve
# Epoch 39/50
#  - 61s - loss: 0.4301 - acc: 0.8484 - val_loss: 0.7511 - val_acc: 0.7510
#
# Epoch 00039: val_loss did not improve
# Epoch 40/50
#  - 62s - loss: 0.4220 - acc: 0.8492 - val_loss: 0.7699 - val_acc: 0.7490
#
# Epoch 00040: val_loss did not improve
# Epoch 41/50
#  - 62s - loss: 0.4159 - acc: 0.8519 - val_loss: 0.7369 - val_acc: 0.7560
#
# Epoch 00041: val_loss did not improve
# Epoch 42/50
#  - 65s - loss: 0.4147 - acc: 0.8526 - val_loss: 0.7560 - val_acc: 0.7538
#
# Epoch 00042: val_loss did not improve
# Epoch 43/50
#  - 64s - loss: 0.4086 - acc: 0.8531 - val_loss: 0.7654 - val_acc: 0.7586
#
# Epoch 00043: val_loss did not improve
# Epoch 44/50
#  - 65s - loss: 0.4086 - acc: 0.8537 - val_loss: 0.7675 - val_acc: 0.7466
#
# Epoch 00044: val_loss did not improve
# Epoch 45/50
#  - 57s - loss: 0.4144 - acc: 0.8534 - val_loss: 0.7797 - val_acc: 0.7524
#
# Epoch 00045: val_loss did not improve
# Epoch 46/50
#  - 46s - loss: 0.4080 - acc: 0.8551 - val_loss: 0.7687 - val_acc: 0.7540
#
# Epoch 00046: val_loss did not improve
# Epoch 47/50
#  - 51s - loss: 0.3981 - acc: 0.8595 - val_loss: 0.7965 - val_acc: 0.7446
#
# Epoch 00047: val_loss did not improve
# Epoch 48/50
#  - 47s - loss: 0.3969 - acc: 0.8564 - val_loss: 0.7814 - val_acc: 0.7478
#
# Epoch 00048: val_loss did not improve
# Epoch 49/50
#  - 46s - loss: 0.3924 - acc: 0.8612 - val_loss: 0.8173 - val_acc: 0.7436
#
# Epoch 00049: val_loss did not improve
# Epoch 50/50
#  - 54s - loss: 0.3873 - acc: 0.8630 - val_loss: 0.7866 - val_acc: 0.7520
#
# Epoch 00050: val_loss did not improve

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7367

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
